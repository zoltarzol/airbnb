# %%
import pandas as pd

# %%
df_air_bnb_anvers = pd.read_csv("data/Antwerp/data/listings.csv")

# %%
df_air_bnb_anvers
# Out:
#                       id                                      listing_url  \
# 0                  50904               https://www.airbnb.com/rooms/50904
# 1                 116134              https://www.airbnb.com/rooms/116134
# 2                 218916              https://www.airbnb.com/rooms/218916
# 3                 224333              https://www.airbnb.com/rooms/224333
# 4                 224682              https://www.airbnb.com/rooms/224682
# ...                  ...                                              ...
# 2220            32149487            https://www.airbnb.com/rooms/32149487
# 2221            49763427            https://www.airbnb.com/rooms/49763427
# 2222  704844714222942163  https://www.airbnb.com/rooms/704844714222942163
# 2223            45210405            https://www.airbnb.com/rooms/45210405
# 2224            44426305            https://www.airbnb.com/rooms/44426305
#
#            scrape_id last_scraped       source  \
# 0     20220922191332   2022-09-22  city scrape
# 1     20220922191332   2022-09-22  city scrape
# 2     20220922191332   2022-09-22  city scrape
# 3     20220922191332   2022-09-22  city scrape
# 4     20220922191332   2022-09-22  city scrape
# ...              ...          ...          ...
# 2220  20220922191332   2022-09-22  city scrape
# 2221  20220922191332   2022-09-22  city scrape
# 2222  20220922191332   2022-09-22  city scrape
# 2223  20220922191332   2022-09-22  city scrape
# 2224  20220922191332   2022-09-22  city scrape
#
#                                                    name  \
# 0         aplace/antwerp: cosy suite - fashion district
# 1                         Spacious apartment nearby Mas
# 2            Apartment with terrace in trendy Zurenborg
# 3            Large stylish room in 1930s house + garden
# 4                 APARTMENT ROSCAM - OLD CENTRE ANTWERP
# ...                                                 ...
# 2220          Cosy and quiet stay during Tomorrowland 1
# 2221                                Habitacion amoblada
# 2222                            Privekamer in rijwoning
# 2223  Prachtige rustige studio - apart toilet en keuken
# 2224    Gezellige privé-kamer op de grens met Antwerpen
#
#                                             description  \
# 0     Decorated in a vintage style combined with a f...
# 1     Enjoy your stay at our 4 person apartment in t...
# 2     Do you enjoy authentic places with a lot of ch...
# 3     Large bedroom in classic 1930s house. Kitchen,...
# 4     <b>The space</b><br />Apartment "Roscam" is a ...
# ...                                                 ...
# 2220  Looking for a cosy and calm stay during Tommor...
# 2221  Furnished room in a top location and comfortab...
# 2222  Cosy room in a charming house with private bat...
# 2223  Beste bezoeker, in het historische voorhuis va...
# 2224  Very calm neighbourhood, next to tramstop (tra...
#
#                                   neighborhood_overview  \
# 0                                                   NaN
# 1     The area "`t eilandje" is located at the old h...
# 2     Quiet Zurenborg is home to Cogels-Osylei, a co...
# 3     The house is located in one of the most beauti...
# 4     There is a paid parking lot around the corner....
# ...                                                 ...
# 2220  Transport to the festival :<br />You can take ...
# 2221                                                NaN
# 2222                                                NaN
# 2223                                                NaN
# 2224  Very calm neighbourhood, but very central loca...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/f14b0908-cbc3...     234077
# 1     https://a0.muscache.com/pictures/23732573/0708...     586942
# 2     https://a0.muscache.com/pictures/26af21a7-e0e2...     915664
# 3     https://a0.muscache.com/pictures/miso/Hosting-...    1167377
# 4     https://a0.muscache.com/pictures/cc82d1b9-ec82...    1263933
# ...                                                 ...        ...
# 2220  https://a0.muscache.com/pictures/22d063ed-6a80...  123998866
# 2221  https://a0.muscache.com/pictures/2222924c-4e13...  305343731
# 2222  https://a0.muscache.com/pictures/miso/Hosting-...  118331541
# 2223  https://a0.muscache.com/pictures/miso/Hosting-...    5358001
# 2224  https://a0.muscache.com/pictures/7b785923-78f6...    8023038
#
#                                          host_url host_name  host_since  \
# 0        https://www.airbnb.com/users/show/234077     Karin  2010-09-14
# 1        https://www.airbnb.com/users/show/586942      Gina  2011-05-14
# 2        https://www.airbnb.com/users/show/915664     Laura  2011-08-03
# 3       https://www.airbnb.com/users/show/1167377     Geert  2011-09-16
# 4       https://www.airbnb.com/users/show/1263933  Kristien  2011-10-08
# ...                                           ...       ...         ...
# 2220  https://www.airbnb.com/users/show/123998866      Karo  2017-04-03
# 2221  https://www.airbnb.com/users/show/305343731    Gladys  2019-10-29
# 2222  https://www.airbnb.com/users/show/118331541   Annemie  2017-02-27
# 2223    https://www.airbnb.com/users/show/5358001     Frank  2013-03-07
# 2224    https://www.airbnb.com/users/show/8023038     Laure  2013-08-08
#
#              host_location                                         host_about  \
# 0         Antwerp, Belgium  Ever since my childhood I dreamt of having my ...
# 1         Antwerp, Belgium  We are looking forward to welcome you and help...
# 2         Antwerp, Belgium  I am a photographer and musician. I have a pas...
# 3         Antwerp, Belgium  I am a person with a job in research, and I li...
# 4         Antwerp, Belgium  Hello! My name is Kristien, living and working...
# ...                    ...                                                ...
# 2220     Hemiksem, Belgium  Ik ben een vrouw die geniet van de kleine ding...
# 2221      Mortsel, Belgium                                                NaN
# 2222      Mortsel, Belgium                                                NaN
# 2223  Zwijndrecht, Belgium                                                NaN
# 2224    Antwerpen, Belgium                                                NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  96%
# 1         within an hour               100%                  97%
# 2         within an hour               100%                  73%
# 3         within an hour               100%                  40%
# 4     within a few hours               100%                 100%
# ...                  ...                ...                  ...
# 2220                 NaN                NaN                 100%
# 2221  within a few hours               100%                  90%
# 2222      within an hour               100%                 100%
# 2223  within a few hours                80%                  92%
# 2224      within an hour               100%                  83%
#
#      host_is_superhost                                 host_thumbnail_url  \
# 0                    f  https://a0.muscache.com/im/pictures/user/c4bcd...
# 1                    t  https://a0.muscache.com/im/pictures/user/6f176...
# 2                    f  https://a0.muscache.com/im/users/915664/profil...
# 3                    f  https://a0.muscache.com/im/pictures/user/11ed8...
# 4                    t  https://a0.muscache.com/im/pictures/user/4fe94...
# ...                ...                                                ...
# 2220                 f  https://a0.muscache.com/im/pictures/user/e3120...
# 2221                 t  https://a0.muscache.com/im/pictures/user/bf1fe...
# 2222                 f  https://a0.muscache.com/im/pictures/user/8832f...
# 2223                 f  https://a0.muscache.com/im/pictures/user/7ebf9...
# 2224                 t  https://a0.muscache.com/im/pictures/user/b4734...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/user/c4bcd...                NaN
# 1     https://a0.muscache.com/im/pictures/user/6f176...                NaN
# 2     https://a0.muscache.com/im/users/915664/profil...                NaN
# 3     https://a0.muscache.com/im/pictures/user/11ed8...                NaN
# 4     https://a0.muscache.com/im/pictures/user/4fe94...                NaN
# ...                                                 ...                ...
# 2220  https://a0.muscache.com/im/pictures/user/e3120...                NaN
# 2221  https://a0.muscache.com/im/pictures/user/bf1fe...                NaN
# 2222  https://a0.muscache.com/im/pictures/user/8832f...                NaN
# 2223  https://a0.muscache.com/im/pictures/user/7ebf9...                NaN
# 2224  https://a0.muscache.com/im/pictures/user/b4734...                NaN
#
#       host_listings_count  host_total_listings_count  \
# 0                       4                          4
# 1                       1                          1
# 2                       2                          2
# 3                       2                          2
# 4                       1                          1
# ...                   ...                        ...
# 2220                    4                          4
# 2221                    1                          1
# 2222                    1                          1
# 2223                    5                          5
# 2224                    1                          1
#
#                     host_verifications host_has_profile_pic  \
# 0                   ['email', 'phone']                    t
# 1     ['email', 'phone', 'work_email']                    t
# 2                   ['email', 'phone']                    t
# 3                   ['email', 'phone']                    t
# 4                            ['phone']                    t
# ...                                ...                  ...
# 2220                ['email', 'phone']                    t
# 2221                ['email', 'phone']                    t
# 2222                ['email', 'phone']                    t
# 2223                ['email', 'phone']                    t
# 2224                ['email', 'phone']                    t
#
#      host_identity_verified                      neighbourhood  \
# 0                         t                                NaN
# 1                         t   Antwerp, Flemish Region, Belgium
# 2                         t   Antwerp, Flemish Region, Belgium
# 3                         t     Antwerpen, Vlaanderen, Belgium
# 4                         t  Antwerpen, Vlaams Gewest, Belgium
# ...                     ...                                ...
# 2220                      t      Hemiksem, Vlaanderen, Belgium
# 2221                      t                                NaN
# 2222                      t                                NaN
# 2223                      t                                NaN
# 2224                      t      Borsbeek, Vlaanderen, Belgium
#
#      neighbourhood_cleansed  neighbourhood_group_cleansed   latitude  \
# 0        Historisch Centrum                           NaN  51.218575
# 1                  Eilandje                           NaN  51.230510
# 2                 Zurenborg                           NaN  51.206330
# 3          Deurne Zuid West                           NaN  51.197720
# 4              Sint-Andries                           NaN  51.217220
# ...                     ...                           ...        ...
# 2220             Koornbloem                           NaN  51.153490
# 2221  Nieuw - Kwartier Oost                           NaN  51.172070
# 2222  Nieuw - Kwartier Oost                           NaN  51.174631
# 2223            Linkeroever                           NaN  51.202940
# 2224       Deurne Zuid Oost                           NaN  51.202790
#
#       longitude                       property_type        room_type  \
# 0      4.398631              Room in boutique hotel       Hotel room
# 1      4.405930                  Entire rental unit  Entire home/apt
# 2      4.429420                        Entire condo  Entire home/apt
# 3      4.458530                Private room in home     Private room
# 4      4.397900                  Entire rental unit  Entire home/apt
# ...         ...                                 ...              ...
# 2220   4.345710                Private room in home     Private room
# 2221   4.450510  Private room in serviced apartment     Private room
# 2222   4.442625           Private room in townhouse     Private room
# 2223   4.348500         Private room in rental unit     Private room
# 2224   4.482920                Private room in home     Private room
#
#       accommodates  bathrooms  bathrooms_text  bedrooms  beds  \
# 0                2        NaN  1 private bath       1.0   1.0
# 1                4        NaN       2.5 baths       2.0   2.0
# 2                5        NaN          1 bath       1.0   2.0
# 3                2        NaN  2 shared baths       1.0   1.0
# 4                3        NaN          1 bath       1.0   2.0
# ...            ...        ...             ...       ...   ...
# 2220             2        NaN  2 shared baths       1.0   2.0
# 2221             2        NaN   1 shared bath       1.0   NaN
# 2222             2        NaN  1 private bath       1.0   1.0
# 2223             2        NaN  1 private bath       1.0   1.0
# 2224             2        NaN   1 shared bath       1.0   2.0
#
#                                               amenities    price  \
# 0     ["Long term stays allowed", "Cable TV", "Hot w...  $174.00
# 1     ["Toaster", "Oven", "Long term stays allowed",...  $180.00
# 2     ["Long term stays allowed", "Hot water", "Body...  $100.00
# 3     ["Outdoor furniture", "Long term stays allowed...   $15.00
# 4     ["Long term stays allowed", "Hot water", "Body...  $111.00
# ...                                                 ...      ...
# 2220  ["Oven", "TV", "Hot water", "Body soap", "Hot ...  $100.00
# 2221  ["Paid washer", "Oven", "Long term stays allow...   $46.00
# 2222  ["Free parking garage on premises", "Long term...   $40.00
# 2223  ["Long term stays allowed", "Cable TV", "Hot w...   $65.00
# 2224  ["Long term stays allowed", "Hot water", "Body...   $41.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                  1              60                       1
# 1                  2              30                       2
# 2                  2              50                       2
# 3                 14             365                      14
# 4                  2              30                       1
# ...              ...             ...                     ...
# 2220               3               4                       3
# 2221               3              30                       3
# 2222               1             365                       1
# 2223               3            1125                       3
# 2224               2            1125                       2
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                          3                      60                      60
# 1                          2                    1125                    1125
# 2                          2                      50                      50
# 3                         14                     365                     365
# 4                          2                      30                      30
# ...                      ...                     ...                     ...
# 2220                       3                       4                       4
# 2221                       3                      30                      30
# 2222                       1                     365                     365
# 2223                       3                    1125                    1125
# 2224                       2                    1125                    1125
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                        1.1                    60.0               NaN
# 1                        2.0                  1125.0               NaN
# 2                        2.0                    50.0               NaN
# 3                       14.0                   365.0               NaN
# 4                        2.0                    30.0               NaN
# ...                      ...                     ...               ...
# 2220                     3.0                     4.0               NaN
# 2221                     3.0                    30.0               NaN
# 2222                     1.0                   365.0               NaN
# 2223                     3.0                  1125.0               NaN
# 2224                     2.0                  1125.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 0                   t               14               42               69
# 1                   t                5               30               55
# 2                   t                0                0                0
# 3                   t                3                3                3
# 4                   t                7               24               50
# ...               ...              ...              ...              ...
# 2220                t                0                0                0
# 2221                t               24               54               84
# 2222                t               10               37               67
# 2223                t                0                0                0
# 2224                t                9               39               69
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 0                  249            2022-09-22                  3
# 1                  296            2022-09-22                137
# 2                   78            2022-09-22                 28
# 3                   87            2022-09-22                  4
# 4                  309            2022-09-22                425
# ...                ...                   ...                ...
# 2220                83            2022-09-22                  4
# 2221               359            2022-09-22                 13
# 2222               342            2022-09-22                  1
# 2223               232            2022-09-22                  6
# 2224               159            2022-09-22                 16
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                         2                       0   2015-05-06  2022-05-15
# 1                        24                       0   2012-03-05  2022-08-20
# 2                         0                       0   2011-10-24  2021-09-05
# 3                         1                       0   2011-09-19  2022-08-22
# 4                        81                       9   2012-02-20  2022-09-16
# ...                     ...                     ...          ...         ...
# 2220                      2                       0   2019-07-22  2022-08-01
# 2221                      9                       2   2021-07-18  2022-09-10
# 2222                      1                       1   2022-09-11  2022-09-11
# 2223                      3                       0   2020-09-13  2022-05-07
# 2224                     15                       2   2021-09-12  2022-09-17
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     5.00                    5.00                       5.00
# 1                     4.94                    4.95                       4.97
# 2                     4.57                    4.58                       4.38
# 3                     4.00                    4.67                       2.67
# 4                     4.77                    4.81                       4.84
# ...                    ...                     ...                        ...
# 2220                  5.00                    5.00                       5.00
# 2221                  4.85                    4.92                       5.00
# 2222                  5.00                    5.00                       5.00
# 2223                  5.00                    5.00                       4.67
# 2224                  4.94                    4.88                       4.88
#
#       review_scores_checkin  review_scores_communication  \
# 0                      5.00                         5.00
# 1                      4.92                         4.91
# 2                      4.83                         4.88
# 3                      4.67                         4.00
# 4                      4.90                         4.90
# ...                     ...                          ...
# 2220                   5.00                         5.00
# 2221                   5.00                         4.92
# 2222                   5.00                         5.00
# 2223                   5.00                         5.00
# 2224                   4.88                         5.00
#
#       review_scores_location  review_scores_value  license instant_bookable  \
# 0                       5.00                 5.00      NaN                f
# 1                       4.90                 4.78      NaN                f
# 2                       4.79                 4.50      NaN                f
# 3                       4.67                 4.33      NaN                f
# 4                       4.96                 4.74      NaN                f
# ...                      ...                  ...      ...              ...
# 2220                    5.00                 5.00      NaN                f
# 2221                    4.92                 4.85      NaN                f
# 2222                    5.00                 5.00      NaN                f
# 2223                    4.33                 4.83      NaN                t
# 2224                    4.75                 4.88      NaN                f
#
#       calculated_host_listings_count  \
# 0                                  4
# 1                                  1
# 2                                  1
# 3                                  2
# 4                                  1
# ...                              ...
# 2220                               4
# 2221                               1
# 2222                               1
# 2223                               5
# 2224                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               1
# 2                                               1
# 3                                               0
# 4                                               1
# ...                                           ...
# 2220                                            0
# 2221                                            0
# 2222                                            0
# 2223                                            3
# 2224                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                2
# 4                                                0
# ...                                            ...
# 2220                                             4
# 2221                                             1
# 2222                                             1
# 2223                                             2
# 2224                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.03
# 1                                               0               1.07
# 2                                               0               0.21
# 3                                               0               0.03
# 4                                               0               3.30
# ...                                           ...                ...
# 2220                                            0               0.10
# 2221                                            0               0.90
# 2222                                            0               1.00
# 2223                                            0               0.24
# 2224                                            0               1.28
#
# [2225 rows x 75 columns]

# %%
df_air_bnb_anvers.host_id
# Out:
# 0          234077
# 1          586942
# 2          915664
# 3         1167377
# 4         1263933
#           ...
# 2220    123998866
# 2221    305343731
# 2222    118331541
# 2223      5358001
# 2224      8023038
# Name: host_id, Length: 2225, dtype: int64

# %%
df_air_bnb_anvers.shape
# Out:
# (2225, 75)

# %%
df_air_bnb_anvers.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# source                                           object
#                                                  ...
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# Length: 75, dtype: object

# %%
df_air_bnb_anvers.info
# Out:
# <bound method DataFrame.info of                       id                                      listing_url  \
# 0                  50904               https://www.airbnb.com/rooms/50904
# 1                 116134              https://www.airbnb.com/rooms/116134
# 2                 218916              https://www.airbnb.com/rooms/218916
# 3                 224333              https://www.airbnb.com/rooms/224333
# 4                 224682              https://www.airbnb.com/rooms/224682
# ...                  ...                                              ...
# 2220            32149487            https://www.airbnb.com/rooms/32149487
# 2221            49763427            https://www.airbnb.com/rooms/49763427
# 2222  704844714222942163  https://www.airbnb.com/rooms/704844714222942163
# 2223            45210405            https://www.airbnb.com/rooms/45210405
# 2224            44426305            https://www.airbnb.com/rooms/44426305
#
#            scrape_id last_scraped       source  \
# 0     20220922191332   2022-09-22  city scrape
# 1     20220922191332   2022-09-22  city scrape
# 2     20220922191332   2022-09-22  city scrape
# 3     20220922191332   2022-09-22  city scrape
# 4     20220922191332   2022-09-22  city scrape
# ...              ...          ...          ...
# 2220  20220922191332   2022-09-22  city scrape
# 2221  20220922191332   2022-09-22  city scrape
# 2222  20220922191332   2022-09-22  city scrape
# 2223  20220922191332   2022-09-22  city scrape
# 2224  20220922191332   2022-09-22  city scrape
#
#                                                    name  \
# 0         aplace/antwerp: cosy suite - fashion district
# 1                         Spacious apartment nearby Mas
# 2            Apartment with terrace in trendy Zurenborg
# 3            Large stylish room in 1930s house + garden
# 4                 APARTMENT ROSCAM - OLD CENTRE ANTWERP
# ...                                                 ...
# 2220          Cosy and quiet stay during Tomorrowland 1
# 2221                                Habitacion amoblada
# 2222                            Privekamer in rijwoning
# 2223  Prachtige rustige studio - apart toilet en keuken
# 2224    Gezellige privé-kamer op de grens met Antwerpen
#
#                                             description  \
# 0     Decorated in a vintage style combined with a f...
# 1     Enjoy your stay at our 4 person apartment in t...
# 2     Do you enjoy authentic places with a lot of ch...
# 3     Large bedroom in classic 1930s house. Kitchen,...
# 4     <b>The space</b><br />Apartment "Roscam" is a ...
# ...                                                 ...
# 2220  Looking for a cosy and calm stay during Tommor...
# 2221  Furnished room in a top location and comfortab...
# 2222  Cosy room in a charming house with private bat...
# 2223  Beste bezoeker, in het historische voorhuis va...
# 2224  Very calm neighbourhood, next to tramstop (tra...
#
#                                   neighborhood_overview  \
# 0                                                   NaN
# 1     The area "`t eilandje" is located at the old h...
# 2     Quiet Zurenborg is home to Cogels-Osylei, a co...
# 3     The house is located in one of the most beauti...
# 4     There is a paid parking lot around the corner....
# ...                                                 ...
# 2220  Transport to the festival :<br />You can take ...
# 2221                                                NaN
# 2222                                                NaN
# 2223                                                NaN
# 2224  Very calm neighbourhood, but very central loca...
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/f14b0908-cbc3...     234077
# 1     https://a0.muscache.com/pictures/23732573/0708...     586942
# 2     https://a0.muscache.com/pictures/26af21a7-e0e2...     915664
# 3     https://a0.muscache.com/pictures/miso/Hosting-...    1167377
# 4     https://a0.muscache.com/pictures/cc82d1b9-ec82...    1263933
# ...                                                 ...        ...
# 2220  https://a0.muscache.com/pictures/22d063ed-6a80...  123998866
# 2221  https://a0.muscache.com/pictures/2222924c-4e13...  305343731
# 2222  https://a0.muscache.com/pictures/miso/Hosting-...  118331541
# 2223  https://a0.muscache.com/pictures/miso/Hosting-...    5358001
# 2224  https://a0.muscache.com/pictures/7b785923-78f6...    8023038
#
#                                          host_url host_name  host_since  \
# 0        https://www.airbnb.com/users/show/234077     Karin  2010-09-14
# 1        https://www.airbnb.com/users/show/586942      Gina  2011-05-14
# 2        https://www.airbnb.com/users/show/915664     Laura  2011-08-03
# 3       https://www.airbnb.com/users/show/1167377     Geert  2011-09-16
# 4       https://www.airbnb.com/users/show/1263933  Kristien  2011-10-08
# ...                                           ...       ...         ...
# 2220  https://www.airbnb.com/users/show/123998866      Karo  2017-04-03
# 2221  https://www.airbnb.com/users/show/305343731    Gladys  2019-10-29
# 2222  https://www.airbnb.com/users/show/118331541   Annemie  2017-02-27
# 2223    https://www.airbnb.com/users/show/5358001     Frank  2013-03-07
# 2224    https://www.airbnb.com/users/show/8023038     Laure  2013-08-08
#
#              host_location                                         host_about  \
# 0         Antwerp, Belgium  Ever since my childhood I dreamt of having my ...
# 1         Antwerp, Belgium  We are looking forward to welcome you and help...
# 2         Antwerp, Belgium  I am a photographer and musician. I have a pas...
# 3         Antwerp, Belgium  I am a person with a job in research, and I li...
# 4         Antwerp, Belgium  Hello! My name is Kristien, living and working...
# ...                    ...                                                ...
# 2220     Hemiksem, Belgium  Ik ben een vrouw die geniet van de kleine ding...
# 2221      Mortsel, Belgium                                                NaN
# 2222      Mortsel, Belgium                                                NaN
# 2223  Zwijndrecht, Belgium                                                NaN
# 2224    Antwerpen, Belgium                                                NaN
#
#       host_response_time host_response_rate host_acceptance_rate  \
# 0         within an hour               100%                  96%
# 1         within an hour               100%                  97%
# 2         within an hour               100%                  73%
# 3         within an hour               100%                  40%
# 4     within a few hours               100%                 100%
# ...                  ...                ...                  ...
# 2220                 NaN                NaN                 100%
# 2221  within a few hours               100%                  90%
# 2222      within an hour               100%                 100%
# 2223  within a few hours                80%                  92%
# 2224      within an hour               100%                  83%
#
#      host_is_superhost                                 host_thumbnail_url  \
# 0                    f  https://a0.muscache.com/im/pictures/user/c4bcd...
# 1                    t  https://a0.muscache.com/im/pictures/user/6f176...
# 2                    f  https://a0.muscache.com/im/users/915664/profil...
# 3                    f  https://a0.muscache.com/im/pictures/user/11ed8...
# 4                    t  https://a0.muscache.com/im/pictures/user/4fe94...
# ...                ...                                                ...
# 2220                 f  https://a0.muscache.com/im/pictures/user/e3120...
# 2221                 t  https://a0.muscache.com/im/pictures/user/bf1fe...
# 2222                 f  https://a0.muscache.com/im/pictures/user/8832f...
# 2223                 f  https://a0.muscache.com/im/pictures/user/7ebf9...
# 2224                 t  https://a0.muscache.com/im/pictures/user/b4734...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/user/c4bcd...                NaN
# 1     https://a0.muscache.com/im/pictures/user/6f176...                NaN
# 2     https://a0.muscache.com/im/users/915664/profil...                NaN
# 3     https://a0.muscache.com/im/pictures/user/11ed8...                NaN
# 4     https://a0.muscache.com/im/pictures/user/4fe94...                NaN
# ...                                                 ...                ...
# 2220  https://a0.muscache.com/im/pictures/user/e3120...                NaN
# 2221  https://a0.muscache.com/im/pictures/user/bf1fe...                NaN
# 2222  https://a0.muscache.com/im/pictures/user/8832f...                NaN
# 2223  https://a0.muscache.com/im/pictures/user/7ebf9...                NaN
# 2224  https://a0.muscache.com/im/pictures/user/b4734...                NaN
#
#       host_listings_count  host_total_listings_count  \
# 0                       4                          4
# 1                       1                          1
# 2                       2                          2
# 3                       2                          2
# 4                       1                          1
# ...                   ...                        ...
# 2220                    4                          4
# 2221                    1                          1
# 2222                    1                          1
# 2223                    5                          5
# 2224                    1                          1
#
#                     host_verifications host_has_profile_pic  \
# 0                   ['email', 'phone']                    t
# 1     ['email', 'phone', 'work_email']                    t
# 2                   ['email', 'phone']                    t
# 3                   ['email', 'phone']                    t
# 4                            ['phone']                    t
# ...                                ...                  ...
# 2220                ['email', 'phone']                    t
# 2221                ['email', 'phone']                    t
# 2222                ['email', 'phone']                    t
# 2223                ['email', 'phone']                    t
# 2224                ['email', 'phone']                    t
#
#      host_identity_verified                      neighbourhood  \
# 0                         t                                NaN
# 1                         t   Antwerp, Flemish Region, Belgium
# 2                         t   Antwerp, Flemish Region, Belgium
# 3                         t     Antwerpen, Vlaanderen, Belgium
# 4                         t  Antwerpen, Vlaams Gewest, Belgium
# ...                     ...                                ...
# 2220                      t      Hemiksem, Vlaanderen, Belgium
# 2221                      t                                NaN
# 2222                      t                                NaN
# 2223                      t                                NaN
# 2224                      t      Borsbeek, Vlaanderen, Belgium
#
#      neighbourhood_cleansed  neighbourhood_group_cleansed   latitude  \
# 0        Historisch Centrum                           NaN  51.218575
# 1                  Eilandje                           NaN  51.230510
# 2                 Zurenborg                           NaN  51.206330
# 3          Deurne Zuid West                           NaN  51.197720
# 4              Sint-Andries                           NaN  51.217220
# ...                     ...                           ...        ...
# 2220             Koornbloem                           NaN  51.153490
# 2221  Nieuw - Kwartier Oost                           NaN  51.172070
# 2222  Nieuw - Kwartier Oost                           NaN  51.174631
# 2223            Linkeroever                           NaN  51.202940
# 2224       Deurne Zuid Oost                           NaN  51.202790
#
#       longitude                       property_type        room_type  \
# 0      4.398631              Room in boutique hotel       Hotel room
# 1      4.405930                  Entire rental unit  Entire home/apt
# 2      4.429420                        Entire condo  Entire home/apt
# 3      4.458530                Private room in home     Private room
# 4      4.397900                  Entire rental unit  Entire home/apt
# ...         ...                                 ...              ...
# 2220   4.345710                Private room in home     Private room
# 2221   4.450510  Private room in serviced apartment     Private room
# 2222   4.442625           Private room in townhouse     Private room
# 2223   4.348500         Private room in rental unit     Private room
# 2224   4.482920                Private room in home     Private room
#
#       accommodates  bathrooms  bathrooms_text  bedrooms  beds  \
# 0                2        NaN  1 private bath       1.0   1.0
# 1                4        NaN       2.5 baths       2.0   2.0
# 2                5        NaN          1 bath       1.0   2.0
# 3                2        NaN  2 shared baths       1.0   1.0
# 4                3        NaN          1 bath       1.0   2.0
# ...            ...        ...             ...       ...   ...
# 2220             2        NaN  2 shared baths       1.0   2.0
# 2221             2        NaN   1 shared bath       1.0   NaN
# 2222             2        NaN  1 private bath       1.0   1.0
# 2223             2        NaN  1 private bath       1.0   1.0
# 2224             2        NaN   1 shared bath       1.0   2.0
#
#                                               amenities    price  \
# 0     ["Long term stays allowed", "Cable TV", "Hot w...  $174.00
# 1     ["Toaster", "Oven", "Long term stays allowed",...  $180.00
# 2     ["Long term stays allowed", "Hot water", "Body...  $100.00
# 3     ["Outdoor furniture", "Long term stays allowed...   $15.00
# 4     ["Long term stays allowed", "Hot water", "Body...  $111.00
# ...                                                 ...      ...
# 2220  ["Oven", "TV", "Hot water", "Body soap", "Hot ...  $100.00
# 2221  ["Paid washer", "Oven", "Long term stays allow...   $46.00
# 2222  ["Free parking garage on premises", "Long term...   $40.00
# 2223  ["Long term stays allowed", "Cable TV", "Hot w...   $65.00
# 2224  ["Long term stays allowed", "Hot water", "Body...   $41.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                  1              60                       1
# 1                  2              30                       2
# 2                  2              50                       2
# 3                 14             365                      14
# 4                  2              30                       1
# ...              ...             ...                     ...
# 2220               3               4                       3
# 2221               3              30                       3
# 2222               1             365                       1
# 2223               3            1125                       3
# 2224               2            1125                       2
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                          3                      60                      60
# 1                          2                    1125                    1125
# 2                          2                      50                      50
# 3                         14                     365                     365
# 4                          2                      30                      30
# ...                      ...                     ...                     ...
# 2220                       3                       4                       4
# 2221                       3                      30                      30
# 2222                       1                     365                     365
# 2223                       3                    1125                    1125
# 2224                       2                    1125                    1125
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                        1.1                    60.0               NaN
# 1                        2.0                  1125.0               NaN
# 2                        2.0                    50.0               NaN
# 3                       14.0                   365.0               NaN
# 4                        2.0                    30.0               NaN
# ...                      ...                     ...               ...
# 2220                     3.0                     4.0               NaN
# 2221                     3.0                    30.0               NaN
# 2222                     1.0                   365.0               NaN
# 2223                     3.0                  1125.0               NaN
# 2224                     2.0                  1125.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 0                   t               14               42               69
# 1                   t                5               30               55
# 2                   t                0                0                0
# 3                   t                3                3                3
# 4                   t                7               24               50
# ...               ...              ...              ...              ...
# 2220                t                0                0                0
# 2221                t               24               54               84
# 2222                t               10               37               67
# 2223                t                0                0                0
# 2224                t                9               39               69
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 0                  249            2022-09-22                  3
# 1                  296            2022-09-22                137
# 2                   78            2022-09-22                 28
# 3                   87            2022-09-22                  4
# 4                  309            2022-09-22                425
# ...                ...                   ...                ...
# 2220                83            2022-09-22                  4
# 2221               359            2022-09-22                 13
# 2222               342            2022-09-22                  1
# 2223               232            2022-09-22                  6
# 2224               159            2022-09-22                 16
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                         2                       0   2015-05-06  2022-05-15
# 1                        24                       0   2012-03-05  2022-08-20
# 2                         0                       0   2011-10-24  2021-09-05
# 3                         1                       0   2011-09-19  2022-08-22
# 4                        81                       9   2012-02-20  2022-09-16
# ...                     ...                     ...          ...         ...
# 2220                      2                       0   2019-07-22  2022-08-01
# 2221                      9                       2   2021-07-18  2022-09-10
# 2222                      1                       1   2022-09-11  2022-09-11
# 2223                      3                       0   2020-09-13  2022-05-07
# 2224                     15                       2   2021-09-12  2022-09-17
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     5.00                    5.00                       5.00
# 1                     4.94                    4.95                       4.97
# 2                     4.57                    4.58                       4.38
# 3                     4.00                    4.67                       2.67
# 4                     4.77                    4.81                       4.84
# ...                    ...                     ...                        ...
# 2220                  5.00                    5.00                       5.00
# 2221                  4.85                    4.92                       5.00
# 2222                  5.00                    5.00                       5.00
# 2223                  5.00                    5.00                       4.67
# 2224                  4.94                    4.88                       4.88
#
#       review_scores_checkin  review_scores_communication  \
# 0                      5.00                         5.00
# 1                      4.92                         4.91
# 2                      4.83                         4.88
# 3                      4.67                         4.00
# 4                      4.90                         4.90
# ...                     ...                          ...
# 2220                   5.00                         5.00
# 2221                   5.00                         4.92
# 2222                   5.00                         5.00
# 2223                   5.00                         5.00
# 2224                   4.88                         5.00
#
#       review_scores_location  review_scores_value  license instant_bookable  \
# 0                       5.00                 5.00      NaN                f
# 1                       4.90                 4.78      NaN                f
# 2                       4.79                 4.50      NaN                f
# 3                       4.67                 4.33      NaN                f
# 4                       4.96                 4.74      NaN                f
# ...                      ...                  ...      ...              ...
# 2220                    5.00                 5.00      NaN                f
# 2221                    4.92                 4.85      NaN                f
# 2222                    5.00                 5.00      NaN                f
# 2223                    4.33                 4.83      NaN                t
# 2224                    4.75                 4.88      NaN                f
#
#       calculated_host_listings_count  \
# 0                                  4
# 1                                  1
# 2                                  1
# 3                                  2
# 4                                  1
# ...                              ...
# 2220                               4
# 2221                               1
# 2222                               1
# 2223                               5
# 2224                               1
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               1
# 2                                               1
# 3                                               0
# 4                                               1
# ...                                           ...
# 2220                                            0
# 2221                                            0
# 2222                                            0
# 2223                                            3
# 2224                                            0
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                0
# 2                                                0
# 3                                                2
# 4                                                0
# ...                                            ...
# 2220                                             4
# 2221                                             1
# 2222                                             1
# 2223                                             2
# 2224                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.03
# 1                                               0               1.07
# 2                                               0               0.21
# 3                                               0               0.03
# 4                                               0               3.30
# ...                                           ...                ...
# 2220                                            0               0.10
# 2221                                            0               0.90
# 2222                                            0               1.00
# 2223                                            0               0.24
# 2224                                            0               1.28
#
# [2225 rows x 75 columns]>

# %%
df_air_bnb_anvers.host_response_rate
# Out:
# 0       100%
# 1       100%
# 2       100%
# 3       100%
# 4       100%
#         ...
# 2220     NaN
# 2221    100%
# 2222    100%
# 2223     80%
# 2224    100%
# Name: host_response_rate, Length: 2225, dtype: object

# %%
df_air_bnb_anvers.host_acceptance_rate
# Out:
# 0        96%
# 1        97%
# 2        73%
# 3        40%
# 4       100%
#         ...
# 2220    100%
# 2221     90%
# 2222    100%
# 2223     92%
# 2224     83%
# Name: host_acceptance_rate, Length: 2225, dtype: object

# %%
df_air_bnb_anvers.neighbourhood_cleansed.drop_duplicates()
# Out:
# 0                 Historisch Centrum
# 1                           Eilandje
# 2                          Zurenborg
# 3                   Deurne Zuid West
# 4                       Sint-Andries
# 5                          Markgrave
# 6                 Amandus - Atheneum
# 7       Borgerhout Intra Muros Noord
# 9                           Harmonie
# 10       Borgerhout Intra Muros Zuid
# 12                       Linkeroever
# 13                         Stadspark
# 14                  Centraal Station
# 15                              Zuid
# 30                       Stuivenberg
# 32                        Haringrode
# 34                       Groenenhoek
# 35              Oosterveld - Elsdonk
# 36                      Deurne Noord
# 37            Borgerhout Extra Muros
# 43                       Rivierenhof
# 46                     Oud - Berchem
# 53                Universiteitsbuurt
# 63                   Hoboken - Noord
# 67                 Theaterbuurt-Meir
# 72                  Deurne Zuid Oost
# 75                 Hoboken - Centrum
# 84                              Kiel
# 86                       Deurne Oost
# 87                         Brederode
# 105            Nieuw - Kwartier West
# 110                              Dam
# 112                 Petroleum - Zuid
# 133                           Polder
# 181                    Oud - Merksem
# 188            Nieuw - Kwartier Oost
# 209          Deurne Dorp - Gallifort
# 212             Tentoonstellingswijk
# 214                       Middelheim
# 234                  Wilrijk Centrum
# 243                       Nieuwdreef
# 269                           Valaar
# 290                     Nieuw - Zuid
# 339                           Hoogte
# 356                         Tuinwijk
# 364               Hoboken - Zuidoost
# 487                   Ekeren Centrum
# 577                       Leugenberg
# 826                         Luchtbal
# 919                 Lambrechtshoeken
# 1038                       Mariaburg
# 1050                           Lillo
# 1097                            Donk
# 1122                        Neerland
# 1336                 Merksem - Heide
# 1392           Kruininge - Bremweide
# 1394                  Hoboken - West
# 1604                      Koornbloem
# 2138               Deurne Vlieghaven
# Name: neighbourhood_cleansed, dtype: object

# %%
df_air_bnb_anvers.neighbourhood_cleansed.unique()
# Out:
# array(['Historisch Centrum', 'Eilandje', 'Zurenborg', 'Deurne Zuid West',
#        'Sint-Andries', 'Markgrave', 'Amandus - Atheneum',
#        'Borgerhout Intra Muros Noord', 'Harmonie',
#        'Borgerhout Intra Muros Zuid', 'Linkeroever', 'Stadspark',
#        'Centraal Station', 'Zuid', 'Stuivenberg', 'Haringrode',
#        'Groenenhoek', 'Oosterveld - Elsdonk', 'Deurne Noord',
#        'Borgerhout Extra Muros', 'Rivierenhof', 'Oud - Berchem',
#        'Universiteitsbuurt', 'Hoboken - Noord', 'Theaterbuurt-Meir',
#        'Deurne Zuid Oost', 'Hoboken - Centrum', 'Kiel', 'Deurne Oost',
#        'Brederode', 'Nieuw - Kwartier West', 'Dam', 'Petroleum - Zuid',
#        'Polder', 'Oud - Merksem', 'Nieuw - Kwartier Oost',
#        'Deurne Dorp - Gallifort', 'Tentoonstellingswijk', 'Middelheim',
#        'Wilrijk Centrum', 'Nieuwdreef', 'Valaar', 'Nieuw - Zuid',
#        'Hoogte', 'Tuinwijk', 'Hoboken - Zuidoost', 'Ekeren Centrum',
#        'Leugenberg', 'Luchtbal', 'Lambrechtshoeken', 'Mariaburg', 'Lillo',
#        'Donk', 'Neerland', 'Merksem - Heide', 'Kruininge - Bremweide',
#        'Hoboken - West', 'Koornbloem', 'Deurne Vlieghaven'], dtype=object)

# %%
df_air_bnb_anvers.neighbourhood_cleansed.unique().size
# Out:
# 59

# %%
df_air_bnb_anvers.host_id
# Out:
# 0          234077
# 1          586942
# 2          915664
# 3         1167377
# 4         1263933
#           ...
# 2220    123998866
# 2221    305343731
# 2222    118331541
# 2223      5358001
# 2224      8023038
# Name: host_id, Length: 2225, dtype: int64

# %%
df_air_bnb_anvers.host_id.unique().size
# Out:
# 1426

# %%
df_preparation = df_air_bnb_anvers[["host_id","neighbourhood_cleansed","number_of_reviews"]]
df_groupby = df_preparation.groupby(by="neighbourhood_cleansed").apply(lambda s: pd.Series({ 
    "host_id nunique": s["host_id"].nunique(), 
    "number_of_reviews sum": s["number_of_reviews"].sum(), 

}))
df_groupby
# Out:
#                               host_id nunique  number_of_reviews sum
# neighbourhood_cleansed
# Amandus - Atheneum                        125                   6356
# Borgerhout Extra Muros                     34                   1219
# Borgerhout Intra Muros Noord               50                   2676
# Borgerhout Intra Muros Zuid                57                   2556
# Brederode                                  61                   1359
# Centraal Station                           70                   4020
# Dam                                        19                    210
# Deurne Dorp - Gallifort                    13                    353
# Deurne Noord                               14                    519
# Deurne Oost                                 5                    109
# Deurne Vlieghaven                           3                    216
# Deurne Zuid Oost                           19                    476
# Deurne Zuid West                           19                   1151
# Donk                                        3                     68
# Eilandje                                   51                   2155
# Ekeren Centrum                              2                    181
# Groenenhoek                                22                    603
# Haringrode                                 45                   1313
# Harmonie                                   44                   1941
# Historisch Centrum                        142                  19778
# Hoboken - Centrum                          12                    241
# Hoboken - Noord                            11                     58
# Hoboken - West                              2                     76
# Hoboken - Zuidoost                          1                     12
# Hoogte                                     13                    220
# Kiel                                       15                    335
# Koornbloem                                 17                    167
# Kruininge - Bremweide                       3                     40
# Lambrechtshoeken                            3                      5
# Leugenberg                                  3                     82
# Lillo                                       1                     14
# Linkeroever                                26                    850
# Luchtbal                                    1                      3
# Mariaburg                                   6                     78
# Markgrave                                  27                    550
# Merksem - Heide                             8                    267
# Middelheim                                  8                    224
# Neerland                                    4                     33
# Nieuw - Kwartier Oost                      21                    162
# Nieuw - Kwartier West                      15                    173
# Nieuw - Zuid                                6                    105
# Nieuwdreef                                  7                     64
# Oosterveld - Elsdonk                       21                    151
# Oud - Berchem                              45                   1598
# Oud - Merksem                              14                    211
# Petroleum - Zuid                            4                    140
# Polder                                      3                    335
# Rivierenhof                                 2                      7
# Sint-Andries                               79                   3460
# Stadspark                                  61                   2473
# Stuivenberg                                49                   2158
# Tentoonstellingswijk                        8                    190
# Theaterbuurt-Meir                          93                   6910
# Tuinwijk                                    1                    249
# Universiteitsbuurt                         65                   6122
# Valaar                                      5                    199
# Wilrijk Centrum                             8                    155
# Zuid                                       92                   3128
# Zurenborg                                  25                    871

# %%
df_correction_host_response_rate = df_air_bnb_anvers.host_response_rate.str.replace('%','')
df_correction_host_response_rate_modifie= pd.to_numeric(df_correction_host_response_rate)
df_correction_host_response_rate_modifie = df_correction_host_response_rate_modifie.fillna(df_correction_host_response_rate_modifie.median())
df_recherche_valeur_etrange = df_correction_host_response_rate_modifie.sort_values()
df_correction_host_response_rate_modifie .mean()
# Out:
# 95.15056179775281

# %%
df_correction_host_response_rate = df_air_bnb_anvers.host_response_rate.str.replace('%','')
df_correction_host_response_rate_videe = df_correction_host_response_rate.dropna()
df_correction_host_response_rate_videe= pd.to_numeric(df_correction_host_response_rate_videe)
df_correction_host_response_rate_videe.mean()
# Out:
# 94.5228426395939

# %%
df_correction_host_acceptance_rate = df_air_bnb_anvers.host_acceptance_rate.str.replace('%','')
df_correction_host_acceptance_rate_modifie= pd.to_numeric(df_correction_host_acceptance_rate)
df_correction_host_acceptance_rate_modifie = df_correction_host_acceptance_rate_modifie.fillna(df_correction_host_acceptance_rate_modifie.median())
df_recherche_valeur_etrange = df_correction_host_acceptance_rate_modifie.sort_values()
df_correction_host_acceptance_rate_modifie .mean()
# Out:
# 86.8314606741573

# %%
df_correction_host_acceptance_rate = df_air_bnb_anvers.host_acceptance_rate.str.replace('%','')
df_correction_host_acceptance_rate_videe = df_correction_host_acceptance_rate.dropna()
df_correction_host_acceptance_rate_videe= pd.to_numeric(df_correction_host_acceptance_rate_videe)
df_correction_host_acceptance_rate_videe.mean()
# Out:
# 85.94274623968947

# %%
pd.options.display.max_columns = None
df_air_bnb_anvers.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
'host_verifications'
# Out:
# 'host_verifications'

# %%
df_air_bnb_anvers.host_verifications
# Out:
# 0                     ['email', 'phone']
# 1       ['email', 'phone', 'work_email']
# 2                     ['email', 'phone']
# 3                     ['email', 'phone']
# 4                              ['phone']
#                       ...
# 2220                  ['email', 'phone']
# 2221                  ['email', 'phone']
# 2222                  ['email', 'phone']
# 2223                  ['email', 'phone']
# 2224                  ['email', 'phone']
# Name: host_verifications, Length: 2225, dtype: object
